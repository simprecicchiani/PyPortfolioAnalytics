# %%
from logic_yf import Portfolio
# from logic_av import Portfolio

# %%
portfolio = Portfolio('./samples/sample-portfolio.csv', 'USD')

# %%
portfolio.process_data()

# %%
portfolio.run_benchmark('SPY')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
portfolio.benchmark.plot()
# Out:
# <AxesSubplot:>

# %%
portfolio.holdings.iloc[-1].plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-07-26 00:00:00'>

# %%
portfolio.xirr, portfolio.xirr_ann
# Out:
# (0.416589656898204, 0.21063621305024793)

# %%
portfolio.cash_flows.plot()
# Out:
# <AxesSubplot:>

# %%
portfolio.value[-1]
# Out:
# 137820.463840332
